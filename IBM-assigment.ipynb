# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __FERAS__ __FAID__

# %% [markdown]
# Junior Data Analyst

# %% [markdown]
# _I am interested in data science because I believe it's the world's next commodity. It can also save lives and solve sophisticated issues in a reliable manner._

# %% [markdown]
# ### The following code prints the phrase hello world ###

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# * bulllet point 1
# * bullet point 2
#
# 1. numbered list 1
# 2. numbered list 2
# 3.
